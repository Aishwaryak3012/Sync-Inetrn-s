# %% [markdown]
# # Name: Aishwarya Khairnar

# %% [markdown]
# # Task4: Sign Language Classification

# %% [markdown]
# ### Importing Dataset

# %%
import pandas as pd
df_train = pd.read_csv('sign_mnist_train.csv')
df_train.head(-5)
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0         3     107     118     127     134     139     143     146     150
# 1         6     155     157     156     156     156     157     156     158
# 2         2     187     188     188     187     187     186     187     188
# 3         2     211     211     212     212     211     210     211     210
# 4        13     164     167     170     172     176     179     180     184
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2407     11     162     164     167     171     175     179     181     183
# 2408      2     176     176     175     177     176     177     177     177
# 2409     24     160     161     164     165     167     166     166     167
# 2410      7     122     122     122     122     123     123     123     124
# 2411      8     116     122     136     148     153     157     161     164
#
#       pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0        153  ...     207.0     207.0     207.0     207.0     206.0     206.0
# 1        158  ...      69.0     149.0     128.0      87.0      94.0     163.0
# 2        187  ...     202.0     201.0     200.0     199.0     198.0     199.0
# 3        210  ...     235.0     234.0     233.0     231.0     230.0     226.0
# 4        185  ...      92.0     105.0     105.0     108.0     133.0     163.0
# ...      ...  ...       ...       ...       ...       ...       ...       ...
# 2407     185  ...     138.0     137.0     135.0     135.0     135.0     134.0
# 2408     177  ...     223.0     223.0     222.0     222.0     222.0     221.0
# 2409     167  ...     205.0     205.0     203.0     202.0     201.0     199.0
# 2410     125  ...     165.0     165.0     165.0     163.0     163.0     163.0
# 2411     167  ...     212.0     215.0     215.0     216.0     218.0     218.0
#
#       pixel781  pixel782  pixel783  pixel784
# 0        206.0     204.0     203.0     202.0
# 1        175.0     103.0     135.0     149.0
# 2        198.0     195.0     194.0     195.0
# 3        225.0     222.0     229.0     163.0
# 4        157.0     163.0     164.0     179.0
# ...        ...       ...       ...       ...
# 2407     135.0     149.0     205.0     228.0
# 2408     220.0     220.0     217.0     217.0
# 2409     196.0     195.0     194.0     192.0
# 2410     145.0     131.0     138.0     128.0
# 2411     217.0     217.0     217.0     217.0
#
# [2412 rows x 785 columns]

# %%
df_test = pd.read_csv("sign_mnist_test.csv")
df_test.head(-5)
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0         6     149     149     150     150     150     151     151     150
# 1         5     126     128     131     132     133     134     135     135
# 2        10      85      88      92      96     105     123     135     143
# 3         0     203     205     207     206     207     209     210     209
# 4         3     188     191     193     195     199     201     202     203
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     10     130     131     131     134     133     135     137     136
# 7163      4     158     161     165     169     172     175     177     179
# 7164     14     141     144     146     149     153     156     158     161
# 7165      8     158     160     160     161     161     161     164     162
# 7166     12     169     173     177     181     183     186     189     191
#
#       pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0        151  ...       138       148       127        89        82        96
# 1        136  ...        47       104       194       183       186       184
# 2        147  ...        68       166       242       227       230       227
# 3        210  ...       154       248       247       248       253       236
# 4        203  ...        26        40        64        48        29        46
# ...      ...  ...       ...       ...       ...       ...       ...       ...
# 7162     136  ...       128       106       107        63        11       147
# 7163     181  ...        78       122       141       141       141       140
# 7164     161  ...       199       203       202       201       201       201
# 7165     162  ...       177       178       176       174       173       172
# 7166     194  ...        36        27        14        35        40        15
#
#       pixel781  pixel782  pixel783  pixel784
# 0          106       112       120       107
# 1          184       184       182       180
# 2          226       225       224       222
# 3          230       240       253       255
# 4           49        46        46        53
# ...        ...       ...       ...       ...
# 7162       194       182       176       124
# 7163       141       142       143       144
# 7164       200       200       201       201
# 7165       171       169       169       167
# 7166         8        27        42        41
#
# [7167 rows x 785 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (16,16))
img = plt.imread('amer_sign2.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense, Dropout
import warnings

sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read,Prepare and Split Data

# %%
y_train = df_train['label']
df_train.drop(['label'], axis=1, inplace=True)
df_train.head(-5)
# Out:
#       pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0        107     118     127     134     139     143     146     150     153
# 1        155     157     156     156     156     157     156     158     158
# 2        187     188     188     187     187     186     187     188     187
# 3        211     211     212     212     211     210     211     210     210
# 4        164     167     170     172     176     179     180     184     185
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2407     162     164     167     171     175     179     181     183     185
# 2408     176     176     175     177     176     177     177     177     177
# 2409     160     161     164     165     167     166     166     167     167
# 2410     122     122     122     122     123     123     123     124     125
# 2411     116     122     136     148     153     157     161     164     167
#
#       pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 

X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (2072, 28, 28, 1)
# X_test shape: (688, 28, 28, 1)

# %% [markdown]
# ### Data Augmentation

# %%
datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             width_shift_range=.2, height_shift_range=.2,
                             rotation_range=30,
                             brightness_range=[0.8, 1.2],
                             horizontal_flip=True)

datagenRescale = ImageDataGenerator(rescale=1./255)

X_train = datagen.flow(X_train, y_train, batch_size=batch)

X_test = datagenRescale.flow(X_test, y_test)

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i+1)
    for X_batch, Y_batch in X_train:
        image = X_batch[i]
        plt.imshow(image, cmap='gray')
        plt.xlabel(alphabet[Y_batch[i]])
        break
plt.show()

# %%
checkpoint_filepath = 'best_model.hdf5'

callback_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True)
callback_learningrate = ReduceLROnPlateau(monitor='loss', mode='min', min_delta=0.01, patience=3, factor=.75, min_lr=0.00001, verbose=1)

callbacks = [callback_checkpoint, callback_learningrate]

# %% [markdown]
# ### Design - The Neural Network

# %%
Model = Sequential([Conv2D(filters=32,  kernel_size=(3,3), activation="relu", input_shape=(size,size,channels)),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),

                    Conv2D(filters=128,  kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),

                    Conv2D(filters=512, kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),


                    Flatten(),

                    Dense(units=4096, activation="relu"),
                    Dropout(0.2),

                    Dense(units=1024, activation="relu"),
                    Dropout(0.2),

                    Dense(units=256, activation="relu"),
                    Dropout(0.2),

                    Dense(units=25, activation="softmax"),
])


Model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=["accuracy"])


Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 13, 13, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 128)       36992
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 512)         590336
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 4096)              8392704
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_1 (Dense)             (None, 1024)              4195328
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 256)               262400
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 25)                6425
#
# =================================================================
# Total params: 13484505 (51.44 MB)
# Trainable params: 13484505 (51.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training...

# %%
history = Model.fit(X_train, validation_data=X_test, epochs=100, callbacks=callbacks)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 9s 148ms/step - loss: 3.2130 - accuracy: 0.0434 - val_loss: nan - val_accuracy: 0.0436 - lr: 0.0010
# Epoch 2/100
# 17/17 [==============================] - 2s 114ms/step - loss: 3.1988 - accuracy: 0.0401 - val_loss: nan - val_accuracy: 0.0349 - lr: 0.0010
# Epoch 3/100
# 17/17 [==============================] - 1s 81ms/step - loss: 3.1889 - accuracy: 0.0473 - val_loss: nan - val_accuracy: 0.0363 - lr: 0.0010
# Epoch 4/100
# 17/17 [==============================] - 2s 92ms/step - loss: 3.1858 - accuracy: 0.0512 - val_loss: nan - val_accuracy: 0.0363 - lr: 0.0010
# Epoch 5/100
# 17/17 [==============================] - 2s 87ms/step - loss: 3.1730 - accuracy: 0.0444 - val_loss: nan - val_accuracy: 0.0436 - lr: 0.0010
# Epoch 6/100
# 17/17 [==============================] - 1s 85ms/step - loss: 3.1381 - accuracy: 0.0555 - val_loss: nan - val_accuracy: 0.0305 - lr: 0.0010
# Epoch 7/100
# 17/17 [==============================] - 2s 107ms/step - loss: 3.0670 - accuracy: 0.0724 - val_loss: nan - val_accuracy: 0.0698 - lr: 0.0010
100
# 17/17 [==============================] - 2s 115ms/step - loss: 0.6863 - accuracy: 0.7630 - val_loss: nan - val_accuracy: 0.9186 - lr: 5.6250e-04
# Epoch 88/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6540 - accuracy: 0.7812
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# 17/17 [==============================] - 1s 82ms/step - loss: 0.6515 - accuracy: 0.7819 - val_loss: nan - val_accuracy: 0.9302 - lr: 5.6250e-04
# Epoch 89/100
# 17/17 [==============================] - 1s 81ms/step - loss: 0.6506 - accuracy: 0.7698 - val_loss: nan - val_accuracy: 0.9331 - lr: 4.2187e-04
# Epoch 90/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.6128 - accuracy: 0.7876 - val_loss: nan - val_accuracy: 0.8997 - lr: 4.2187e-04
# Epoch 91/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6208 - accuracy: 0.7901
# Epoch 91: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# 17/17 [==============================] - 2s 111ms/step - loss: 0.6208 - accuracy: 0.7901 - val_loss: nan - val_accuracy: 0.9390 - lr: 4.2187e-04
# Epoch 92/100
# 17/17 [==============================] - 1s 81ms/step - loss: 0.6216 - accuracy: 0.7881 - val_loss: nan - val_accuracy: 0.9375 - lr: 3.1641e-04
# Epoch 93/100
# 17/17 [==============================] - 2s 116ms/step - loss: 0.6210 - accuracy: 0.7862 - val_loss: nan - val_accuracy: 0.9331 - lr: 3.1641e-04
# Epoch 94/100
# 17/17 [==============================] - 2s 91ms/step - loss: 0.6037 - accuracy: 0.7809 - val_loss: nan - val_accuracy: 0.9331 - lr: 3.1641e-04
# Epoch 95/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.6088 - accuracy: 0.7891 - val_loss: nan - val_accuracy: 0.9273 - lr: 3.1641e-04
# Epoch 96/100
# 17/17 [==============================] - 2s 110ms/step - loss: 0.5915 - accuracy: 0.7934 - val_loss: nan - val_accuracy: 0.9578 - lr: 3.1641e-04
# Epoch 97/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.5882 - accuracy: 0.7896 - val_loss: nan - val_accuracy: 0.9549 - lr: 3.1641e-04
# Epoch 98/100
# 17/17 [==============================] - 1s 81ms/step - loss: 0.5904 - accuracy: 0.7867 - val_loss: nan - val_accuracy: 0.9157 - lr: 3.1641e-04
# Epoch 99/100
# 17/17 [==============================] - 2s 117ms/step - loss: 0.5685 - accuracy: 0.7997 - val_loss: nan - val_accuracy: 0.9390 - lr: 3.1641e-04
# Epoch 100/100
# 17/17 [==============================] - 2s 107ms/step - loss: 0.5660 - accuracy: 0.7939 - val_loss: nan - val_accuracy: 0.9506 - lr: 3.1641e-04

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Evaluate the Model

# %%
score = Model.evaluate(X_test)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.9506
# Test loss: nan
# Test accuracy: 0.9505813717842102

# %%
df_test = pd.read_csv("sign_mnist_test.csv")
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

# %% [markdown]
# ### Confusion Matrix

# %%
y_pred = np.argmax(Model.predict(X_test),axis = 1)
# Out:
# 225/225 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (15,15))
sns.heatmap(CM, annot=True, cmap="Blues", fmt = 'g')
plt.xlabel("Predicted Classes")
plt.ylabel("True Classes")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ### Let's Test the Model

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i],cmap='gray')
    plt.ylabel(f"True: {alphabet[y_test[i]]}")
    plt.xlabel(f"Predicted: {alphabet[y_pred[i]]}")

plt.show()
